# %%
Buckets = {"Bucket_3L": 3,
           "Bucket_5L": 5,
           "Bucket_8L": 8}

def bucket_puzzle():
    Bucket_3L = 0
    Bucket_5L = 0
    Bucket_8L = 0
    
    Bucket_5L = Buckets['Bucket_5L']
    
    print("Fill the 5L bucket")
    print(f"3L Bucket contains {Bucket_3L}L")
    print(f"5L Bucket contains {Bucket_5L}L")
    print(f"8L Bucket contains {Bucket_8L}L")
    
    if Bucket_5L > Buckets['Bucket_3L']:
        
        Bucket_3L = Buckets['Bucket_3L']
        Bucket_5L = Bucket_5L - Buckets["Bucket_3L"]
        
        print("Empty the 5L Bucket into the 3L bucket, leaving 2 liters into the 5L Bucket")
        print(f"3L Bucket contains {Bucket_3L}L")
        print(f"5L Bucket contains {Bucket_5L}L")
        print(f"8L Bucket contains {Bucket_8L}L")
        
        Bucket_3L = 0
        
        print("Pour out the contents of the 3L Bucket")
        print(f"3L Bucket contains {Bucket_3L}L")
        print(f"5L Bucket contains {Bucket_5L}L")
        print(f"8L Bucket contains {Bucket_8L}L")
        
        Bucket_3L = Bucket_3L + Bucket_5L
        Bucket_5L = 0
        print("Fill the 3L Bucket with the 2L from the 5L Bucket")
        print(f"3L Bucket contains {Bucket_3L}L")
        print(f"5L Bucket contains {Bucket_5L}L")
        print(f"8L Bucket contains {Bucket_8L}L")
        
        Bucket_5L = Buckets['Bucket_5L']
        
        print("Fill the 5L Bucket")
        print(f"3L Bucket contains {Bucket_3L}L")
        print(f"5L Bucket contains {Bucket_5L}L")
        print(f"8L Bucket contains {Bucket_8L}L")
        
        if Bucket_3L == 2:
            
            Bucket_5L = Bucket_5L - (Buckets['Bucket_3L'] - Bucket_3L)
            Bucket_3L = Buckets['Bucket_3L']
            
            print("Fill the remaining 1 liter space in the 3L Bucket, leaving 4L in the 5L Bucket")
            print(f"3L Bucket contains {Bucket_3L}L")
            print(f"5L Bucket contains {Bucket_5L}L")
            print(f"8L Bucket contains {Bucket_8L}L")
    else:
        Bucket_3L = Buckets_5L

bucket_puzzle()
# Out:
# Fill the 5L bucket
# 3L Bucket contains 0L
# 5L Bucket contains 5L
# 8L Bucket contains 0L
# Empty the 5L Bucket into the 3L bucket, leaving 2 liters into the 5L Bucket
# 3L Bucket contains 3L
# 5L Bucket contains 2L
# 8L Bucket contains 0L
# Pour out the contents of the 3L Bucket
# 3L Bucket contains 0L
# 5L Bucket contains 2L
# 8L Bucket contains 0L
# Fill the 3L Bucket with the 2L from the 5L Bucket
# 3L Bucket contains 2L
# 5L Bucket contains 0L
# 8L Bucket contains 0L
# Fill the 5L Bucket
# 3L Bucket contains 2L
# 5L Bucket contains 5L
# 8L Bucket contains 0L
# Fill the remaining 1 liter space in the 3L Bucket, leaving 4L in the 5L Bucket
# 3L Bucket contains 3L
# 5L Bucket contains 4L
# 8L Bucket contains 0L
